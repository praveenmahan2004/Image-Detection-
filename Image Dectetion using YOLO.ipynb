# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
import os
if not os.path.isdir("yolov8session"):
  os.makedirs("yolov8session")

# %%
# %cd yolov8session
# Out:
# /content/gdrive/MyDrive/yolov8session

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# %cd ultralytics
# Out:
# /content/gdrive/MyDrive/yolov8session/ultralytics

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.4/591.4 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 20.7 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source='Remo.jpg'
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 370, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 107, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 156, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 441, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 379, in torch_safe_load
#     file = attempt_download_asset(weight)  # search online if missing locally
# ...

# %%
# !yolo task=classify mode=predict task=classify source='/content/gdrive/MyDrive/yolov8session/ultralytics/LCU.mp4'
# Out:
# ...
# 100% 5.28M/5.28M [00:00<00:00, 67.6MB/s]
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients
#
# video 1/1 (1/3264) /content/gdrive/MyDrive/yolov8session/ultralytics/LCU.mp4: 224x224 web_site 0.06, spotlight 0.04, stopwatch 0.03, envelope 0.03, perfume 0.03, 2.7ms
# video 1/1 (2/3264) /content/gdrive/MyDrive/yolov8session/ultralytics/LCU.mp4: 224x224 web_site 0.06, spotlight 0.04, stopwatch 0.03, envelope 0.03, perfume 0.03, 3.1ms
# video 1/1 (3/3264) /content/gdrive/MyDrive/yolov8session/ultralytics/LCU.mp4: 224x224 web_site 0.06, spotlight 0.04, stopwatch 0.03, envelope 0.03, perfume 0.03, 2.6ms
# video 1/1 (4/3264) /content/gdrive/MyDrive/yolov8session/ultralytics/LCU.mp4: 224x224 web_site 0.06, spotlight 0.04, envelope 0.03, stopwatch 0.03, perfume 0.03, 3.0ms
# ...

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=custom_data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo predict model=runs/detect/train8/weights/best.pt source='pet.jpeg'
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# Model summary (fused): 268 layers, 68133198 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/pet.jpeg: 352x640 2 cats, 1 dog, 2775.3ms
# Speed: 16.5ms preprocess, 2775.3ms inference, 36.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict17

# %%
# !yolo predict model=runs/detect/train8/weights/best.pt source='bb.mp4'
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68133198 parameters, 0 gradients
#
# video 1/1 (1/587) /content/gdrive/MyDrive/yolov8session/ultralytics/bb.mp4: 640x384 1 cow, 1 horse, 61.5ms
# video 1/1 (2/587) /content/gdrive/MyDrive/yolov8session/ultralytics/bb.mp4: 640x384 1 cow, 1 horse, 50.8ms
# video 1/1 (3/587) /content/gdrive/MyDrive/yolov8session/ultralytics/bb.mp4: 640x384 (no detections), 44.2ms
# video 1/1 (4/587) /content/gdrive/MyDrive/yolov8session/ultralytics/bb.mp4: 640x384 (no detections), 35.0ms
# video 1/1 (5/587) /content/gdrive/MyDrive/yolov8session/ultralytics/bb.mp4: 640x384 (no detections), 34.8ms
# video 1/1 (6/587) /content/gdrive/MyDrive/yolov8session/ultralytics/bb.mp4: 640x384 1 horse, 34.1ms
# video 1/1 (7/587) /content/gdrive/MyDrive/yolov8session/ultralytics/bb.mp4: 640x384 (no detections), 34.0ms
# ...
